# %%
# Q1
from math import pi,e,sin
x=sin(0)
x1=sin(30)
x2=sin(45)
x3=sin(60)
x4=sin(90)
x5=sin(180)
y=pi*3
z=e
print(x1)
print(x2)
print(x1)
print(x)
print(x3)
print(x4)
print(x5)
print(y)
print(z)
# Out:
# -0.9880316240928618
# 0.8509035245341184
# -0.9880316240928618
# 0.0
# -0.3048106211022167
# 0.8939966636005579
# -0.8011526357338304
# 9.42477796076938
# 2.718281828459045

# %%
# Q2
import math
help(math)
help(int)
help('class')
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
# Q3
my_name = ('adnan samad')
print(len(my_name))
# Out:
# 11

# %%
# Q4
name =('adnan samad')
DOB = ('12-12-2000')
cell_number = ('03332423183')
email = ('adnansamad073@gmail.com')
fav_dish = ('chiness')
fav_color = ('Blue')
fav_movie = ('no one')
fav_flower = ('Daffodil')
print(type(name))
print(type(DOB))
print(type(cell_number))
print(type(email))
print(type(fav_dish))
print(type(fav_color))
print(type(fav_movie))
print(type(fav_flower))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Q5
from math import sin
h=1
v=15
g= (-9.8)
angle=30
i=1
h=v*sin(angle)/g
print("the max height above the ground is "+str(h)+"m")
t=2*v*sin(angle)/g
print("Totle time in the air is "+str(t)+"s")
d=v**2*sin(2*angle)/g
print("Totle distance travelled "+str(d)+"m")
vx=v*i
print("Velocity vector at max height is "+str(vx)+"m/s")
print("velocity when the ball hits the ground:The ball has maximum velocity ")
# Out:
# the max height above the ground is 1.5122933021829517m
# Totle time in the air is 3.0245866043659033s
# Totle distance travelled 6.998203035510077m
# Velocity vector at max height is 15m/s
# velocity when the ball hits the ground:The ball has maximum velocity

# %%
# Q6
from math import cos,sin
a1=30
a2=45
a3=60
m=5
g=9.8
F=10
f=0.4
a=g*sin(30)*(-f/m)
print("acceleration: "+str(a)+"m/s2")
sinx=m*a+f-F/m*g
print("Value of sinx is: "+str(sinx))
cosx=f*m*g
print("Value of cosx is: "+str(cosx))
F1=m*a+f-sin(30)*m*g
print("The force for angle 30 is: "+str(F1)+"N")
F2=m*a+f-sin(45)*m*g
print("The force for angle 45 is: "+str(F2)+"N")
F3=m*a+f-sin(60)*m*g
print("The force for angle 60 is: "+str(F3)+"N")
# Out:
# acceleration: 0.7746167932888038m/s2
# Value of sinx is: -15.326916033555982
# Value of cosx is: 19.6
# The force for angle 30 is: 52.68663354699425N
# The force for angle 45 is: -37.42118873572779N
# The force for angle 60 is: 19.208804400452635N

# %%
# Q10
a=560/320
b=1050/1.75
c=5*1.75
print("The vertical pole cast a shadow: "+str(a)+"times")
print("The length of shadow cast another pole: "+str(b)+"m")
print("The height of the pole is: "+str(c)+"m")
# Out:
# The vertical pole cast a shadow: 1.75times
# The length of shadow cast another pole: 600.0m
# The height of the pole is: 8.75m
